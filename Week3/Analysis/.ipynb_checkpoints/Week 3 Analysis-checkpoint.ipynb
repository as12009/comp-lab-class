# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data=np.loadtxt("/home/as12009/comp-lab-class/Week3/Data/potential.xvg",skiprows=24)

# %%
data[:,1] = data[:,1].astype(float)
plt.plot(data[:,0], data[:,1])
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.xlabel('Energy Minimization Step')
plt.ylabel('Potential Energy (KJ/mol)')
plt.title('Potential Energy v Energy Minim')
plt.show()
plt.savefig('PEvEM.png')

# %%
data1=np.loadtxt("/home/as12009/comp-lab-class/Week3/Data/temperature.xvg",skiprows=24)
data1[:,1] = data1[:,1].astype(float)
plt.plot(data1[:,0], data1[:,1])
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.xlabel('Time (ps)')
plt.ylabel('Temperature (K)')
plt.title('Temperature v Time')
plt.show()
plt.savefig('timevtemp.png')

# %%
data2=np.loadtxt("/home/as12009/comp-lab-class/Week3/Data/pressure.xvg",skiprows=24)
data2[:,1] = data2[:,1].astype(float)
plt.plot(data2[:,0], data2[:,1])
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.xlabel('Time (ps)')
plt.ylabel('Pressure (bar)')
plt.title('Pressure v Time')
plt.show()
plt.savefig('timevpressure.png')

# %%
data3=np.loadtxt("/home/as12009/comp-lab-class/Week3/Data/density.xvg",skiprows=24)
data3[:,1] = data3[:,1].astype(float)
plt.plot(data3[:,0], data3[:,1])
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.xlabel('Time (ps)')
plt.ylabel('Density (kg/m^3)')
plt.title('Density v Time')
plt.show()
plt.savefig('timevdensity.png')
