# %%
# import libraries
import MDAnalysis as mda
import MDAnalysis.analysis.rdf as rdf
import MDAnalysis.analysis.msd as msd
import matplotlib.pyplot as plt
import numpy as np

# %%
topology = "../Data/equil/kalj_T2_n360_v300_10000_1.lammpstrj"

trajectory_prod_T1p5 = "../Data/prod/kalj_T1.5_n360_v300_prod_10000_1.unwrap (1).dcd"
trajectory_prod_T1 = "../Data/prod/kalj_T1_n360_v300_prod_50000_1.unwrap (1).dcd"
trajectory_prod_T0p9 = "../Data/prod/kalj_T0.9_n360_v300_prod_150000_1.unwrap.dcd"
trajectory_prod_T0p8 = "../Data/prod/kalj_T0.8_n360_v300_prod_150000_1.unwrap.dcd"
trajectory_prod_T0p7 = "../Data/prod/kalj_T0.7_n360_v300_prod_180000_1.unwrap.dcd"
trajectory_prod_T0p65 = "../Data/prod/kalj_T0.65_n360_v300_prod_350000_1.unwrap.dcd"
trajectory_prod_T0p6 = "../Data/prod/kalj_T0.6_n360_v300_prod_1000000_1.unwrap.dcd"
trajectory_prod_T0p55 = "../Data/prod/kalj_T0.55_n360_v300_prod_3000000_1.unwrap.dcd"
trajectory_prod_T0p5 = "../Data/prod/kalj_T0.5_n360_v300_prod_10000000_1.unwrap.dcd"
trajectory_prod_T0p475 = "../Data/prod/kalj_T0.475_n360_v300_prod_30000000_1.unwrap.dcd"
trajectory_prod_T0p45 = "../Data/prod/kalj_T0.45_n360_v300_prod_100000000_1.unwrap.dcd"

# %%
traj_T1p5 = mda.Universe(topology, trajectory_prod_T1p5, topology_format="LAMMPSDUMP")
traj_T1 = mda.Universe(topology, trajectory_prod_T1, topology_format='LAMMPSDUMP')
traj_T0p9 = mda.Universe(topology, trajectory_prod_T0p9, topology_format='LAMMPSDUMP')
traj_T0p8 = mda.Universe(topology, trajectory_prod_T0p8, topology_format='LAMMPSDUMP')
traj_T0p7 = mda.Universe(topology, trajectory_prod_T0p7, topology_format='LAMMPSDUMP')
traj_T0p65 = mda.Universe(topology, trajectory_prod_T0p65, topology_format='LAMMPSDUMP')
traj_T0p6 = mda.Universe(topology, trajectory_prod_T0p6, topology_format='LAMMPSDUMP')
traj_T0p55 = mda.Universe(topology, trajectory_prod_T0p55, topology_format='LAMMPSDUMP')
traj_T0p5 = mda.Universe(topology, trajectory_prod_T0p5, topology_format='LAMMPSDUMP')
traj_T0p475 = mda.Universe(topology, trajectory_prod_T0p475, topology_format='LAMMPSDUMP')
traj_T0p45 = mda.Universe(topology, trajectory_prod_T0p45, topology_format='LAMMPSDUMP')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In [19], line 2
#       1 # load traj with mdanalysis universe
# ----> 2 traj_T1p5 = mda.Universe(topology, trajectory_prod_T1p5, topology_format="LAMMPSDUMP")
#       3 traj_T1 = mda.Universe(topology, trajectory_prod_T1, topology_format='LAMMPSDUMP')
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/core/universe.py:346, in Universe.__init__(self, topology, all_coordinates, format, topology_format, transformations, guess_bonds, vdwradii, in_memory, in_memory_step, *coordinates, **kwargs)
#     345     self.filename = _check_file_like(topology)
# --> 346     topology = _topology_from_file_like(self.filename,
#     347                                         topology_format=topology_format,
#     348                                         **kwargs)
#     350 if topology is not None:
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/core/universe.py:118, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     115 if (err.errno is not None and
#     116     errno.errorcode[err.errno] in ['ENOENT', 'EACCES']):
#     117     # Runs if the error is propagated due to no permission / file not found
# --> 118     raise sys.exc_info()[1] from err
#     119 else:
#     120     # Runs when the parser fails
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/core/universe.py:110, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     109     with parser(topology_file) as p:
# --> 110         topology = p.parse(**kwargs)
#     111 except (IOError, OSError) as err:
#     112     # There are 2 kinds of errors that might be raised here:
#     113     # one because the file isn't present
#     114     # or the permissions are bad, second when the parser fails
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/topology/LAMMPSParser.py:598, in LammpsDumpParser.parse(self, **kwargs)
#     597 def parse(self, **kwargs):
# --> 598     with openany(self.filename) as fin:
#     599         fin.readline()  # ITEM TIMESTEP
#
# File /ext3/miniconda3/lib/python3.9/contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/lib/util.py:317, in openany(datasource, mode, reset)
#     275 """Context manager for :func:`anyopen`.
#     276
#     277 Open the `datasource` and close it when the context of the :keyword:`with`
#    (...)
#     315 :func:`anyopen`
#     316 """
# --> 317 stream = anyopen(datasource, mode=mode, reset=reset)
#     318 try:
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/lib/util.py:396, in anyopen(datasource, mode, reset)
#     395 openfunc = read_handlers[ext]
# --> 396 stream = _get_stream(datasource, openfunc, mode=mode)
#     397 if stream is not None:
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/lib/util.py:438, in _get_stream(filename, openfunction, mode)
#     437 if errno.errorcode[err.errno] in ['ENOENT', 'EACCES']:
# --> 438     raise sys.exc_info()[1] from err
#     439 return None
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/lib/util.py:432, in _get_stream(filename, openfunction, mode)
#     431 try:
# --> 432     stream = openfunction(filename, mode=mode)
#     433 except (IOError, OSError) as err:
#     434     # An exception might be raised due to two reasons, first the openfunction is unable to open the file, in this
#     435     # case we have to ignore the error and return None. Second is when openfunction can't open the file because
#     436     # either the file isn't there or the permissions don't allow access.
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/lib/picklable_file_io.py:478, in bz2_pickle_open(name, mode)
#     477 bz_mode = mode.replace("t", "")
# --> 478 binary_file = BZ2Picklable(name, bz_mode)
#     479 if "t" in mode:
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/lib/picklable_file_io.py:266, in BZ2Picklable.__init__(self, name, mode)
#     265 self._bz_mode = mode
# --> 266 super().__init__(name, mode)
#
# File /ext3/miniconda3/lib/python3.9/bz2.py:85, in BZ2File.__init__(self, filename, mode, compresslevel)
#      84 if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 85     self._fp = _builtin_open(filename, mode)
#      86     self._closefp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Data/equil/kalj_T2_n360_v300_10000_1.lammpstrj'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In [19], line 2
#       1 # load traj with mdanalysis universe
# ----> 2 traj_T1p5 = mda.Universe(topology, trajectory_prod_T1p5, topology_format="LAMMPSDUMP")
#       3 traj_T1 = mda.Universe(topology, trajectory_prod_T1, topology_format='LAMMPSDUMP')
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/core/universe.py:346, in Universe.__init__(self, topology, all_coordinates, format, topology_format, transformations, guess_bonds, vdwradii, in_memory, in_memory_step, *coordinates, **kwargs)
#     345     self.filename = _check_file_like(topology)
# --> 346     topology = _topology_from_file_like(self.filename,
#     347                                         topology_format=topology_format,
#     348                                         **kwargs)
#     350 if topology is not None:
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/core/universe.py:118, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     115 if (err.errno is not None and
#     116     errno.errorcode[err.errno] in ['ENOENT', 'EACCES']):
#     117     # Runs if the error is propagated due to no permission / file not found
# --> 118     raise sys.exc_info()[1] from err
#     119 else:
#     120     # Runs when the parser fails
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/core/universe.py:110, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     109     with parser(topology_file) as p:
# --> 110         topology = p.parse(**kwargs)
#     111 except (IOError, OSError) as err:
#     112     # There are 2 kinds of errors that might be raised here:
#     113     # one because the file isn't present
#     114     # or the permissions are bad, second when the parser fails
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/topology/LAMMPSParser.py:598, in LammpsDumpParser.parse(self, **kwargs)
#     597 def parse(self, **kwargs):
# --> 598     with openany(self.filename) as fin:
#     599         fin.readline()  # ITEM TIMESTEP
#
# File /ext3/miniconda3/lib/python3.9/contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/lib/util.py:317, in openany(datasource, mode, reset)
#     275 """Context manager for :func:`anyopen`.
#     276
#     277 Open the `datasource` and close it when the context of the :keyword:`with`
#    (...)
#     315 :func:`anyopen`
#     316 """
# --> 317 stream = anyopen(datasource, mode=mode, reset=reset)
#     318 try:
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/lib/util.py:396, in anyopen(datasource, mode, reset)
#     395 openfunc = read_handlers[ext]
# --> 396 stream = _get_stream(datasource, openfunc, mode=mode)
#     397 if stream is not None:
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/lib/util.py:438, in _get_stream(filename, openfunction, mode)
#     437 if errno.errorcode[err.errno] in ['ENOENT', 'EACCES']:
# --> 438     raise sys.exc_info()[1] from err
#     439 return None
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/lib/util.py:432, in _get_stream(filename, openfunction, mode)
#     431 try:
# --> 432     stream = openfunction(filename, mode=mode)
#     433 except (IOError, OSError) as err:
#     434     # An exception might be raised due to two reasons, first the openfunction is unable to open the file, in this
#     435     # case we have to ignore the error and return None. Second is when openfunction can't open the file because
#     436     # either the file isn't there or the permissions don't allow access.
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/lib/picklable_file_io.py:478, in bz2_pickle_open(name, mode)
#     477 bz_mode = mode.replace("t", "")
# --> 478 binary_file = BZ2Picklable(name, bz_mode)
#     479 if "t" in mode:
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/lib/picklable_file_io.py:266, in BZ2Picklable.__init__(self, name, mode)
#     265 self._bz_mode = mode
# --> 266 super().__init__(name, mode)
#
# File /ext3/miniconda3/lib/python3.9/bz2.py:85, in BZ2File.__init__(self, filename, mode, compresslevel)
#      84 if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 85     self._fp = _builtin_open(filename, mode)
#      86     self._closefp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Data/equil/kalj_T2_n360_v300_10000_1.lammpstrj'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [19], line 2
#       1 # load traj with mdanalysis universe
# ----> 2 traj_T1p5 = mda.Universe(topology, trajectory_prod_T1p5, topology_format="LAMMPSDUMP")
#       3 traj_T1 = mda.Universe(topology, trajectory_prod_T1, topology_format='LAMMPSDUMP')
#       4 traj_T0p9 = mda.Universe(topology, trajectory_prod_T0p9, topology_format='LAMMPSDUMP')
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/core/universe.py:346, in Universe.__init__(self, topology, all_coordinates, format, topology_format, transformations, guess_bonds, vdwradii, in_memory, in_memory_step, *coordinates, **kwargs)
#     344 if not isinstance(topology, Topology) and not topology is None:
#     345     self.filename = _check_file_like(topology)
# --> 346     topology = _topology_from_file_like(self.filename,
#     347                                         topology_format=topology_format,
#     348                                         **kwargs)
#     350 if topology is not None:
#     351     self._topology = topology
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/core/universe.py:118, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     111 except (IOError, OSError) as err:
#     112     # There are 2 kinds of errors that might be raised here:
#     113     # one because the file isn't present
#     114     # or the permissions are bad, second when the parser fails
#     115     if (err.errno is not None and
#     116         errno.errorcode[err.errno] in ['ENOENT', 'EACCES']):
#     117         # Runs if the error is propagated due to no permission / file not found
# --> 118         raise sys.exc_info()[1] from err
#     119     else:
#     120         # Runs when the parser fails
#     121         raise IOError("Failed to load from the topology file {0}"
#     122                         " with parser {1}.\n"
#     123                         "Error: {2}".format(topology_file, parser, err))
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/core/universe.py:110, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     108 try:
#     109     with parser(topology_file) as p:
# --> 110         topology = p.parse(**kwargs)
#     111 except (IOError, OSError) as err:
#     112     # There are 2 kinds of errors that might be raised here:
#     113     # one because the file isn't present
#     114     # or the permissions are bad, second when the parser fails
#     115     if (err.errno is not None and
#     116         errno.errorcode[err.errno] in ['ENOENT', 'EACCES']):
#     117         # Runs if the error is propagated due to no permission / file not found
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/topology/LAMMPSParser.py:598, in LammpsDumpParser.parse(self, **kwargs)
#     597 def parse(self, **kwargs):
# --> 598     with openany(self.filename) as fin:
#     599         fin.readline()  # ITEM TIMESTEP
#     600         fin.readline()  # 0
#
# File /ext3/miniconda3/lib/python3.9/contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     117 del self.args, self.kwds, self.func
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#     121     raise RuntimeError("generator didn't yield") from None
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/lib/util.py:317, in openany(datasource, mode, reset)
#     273 @contextmanager
#     274 def openany(datasource, mode='rt', reset=True):
#     275     """Context manager for :func:`anyopen`.
#     276
#     277     Open the `datasource` and close it when the context of the :keyword:`with`
#    (...)
#     315     :func:`anyopen`
#     316     """
# --> 317     stream = anyopen(datasource, mode=mode, reset=reset)
#     318     try:
#     319         yield stream
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/lib/util.py:396, in anyopen(datasource, mode, reset)
#     394 for ext in ('bz2', 'gz', ''):  # file == '' should be last
#     395     openfunc = read_handlers[ext]
# --> 396     stream = _get_stream(datasource, openfunc, mode=mode)
#     397     if stream is not None:
#     398         break
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/lib/util.py:438, in _get_stream(filename, openfunction, mode)
#     433 except (IOError, OSError) as err:
#     434     # An exception might be raised due to two reasons, first the openfunction is unable to open the file, in this
#     435     # case we have to ignore the error and return None. Second is when openfunction can't open the file because
#     436     # either the file isn't there or the permissions don't allow access.
#     437     if errno.errorcode[err.errno] in ['ENOENT', 'EACCES']:
# --> 438         raise sys.exc_info()[1] from err
#     439     return None
#     440 if mode.startswith('r'):
#     441     # additional check for reading (eg can we uncompress) --- is this needed?
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/lib/util.py:432, in _get_stream(filename, openfunction, mode)
#     430 """Return open stream if *filename* can be opened with *openfunction* or else ``None``."""
#     431 try:
# --> 432     stream = openfunction(filename, mode=mode)
#     433 except (IOError, OSError) as err:
#     434     # An exception might be raised due to two reasons, first the openfunction is unable to open the file, in this
#     435     # case we have to ignore the error and return None. Second is when openfunction can't open the file because
#     436     # either the file isn't there or the permissions don't allow access.
#     437     if errno.errorcode[err.errno] in ['ENOENT', 'EACCES']:
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/lib/picklable_file_io.py:478, in bz2_pickle_open(name, mode)
#     475     raise ValueError("Only read mode ('r', 'rt', 'rb') "
#     476                      "files can be pickled.")
#     477 bz_mode = mode.replace("t", "")
# --> 478 binary_file = BZ2Picklable(name, bz_mode)
#     479 if "t" in mode:
#     480     return TextIOPicklable(binary_file)
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/lib/picklable_file_io.py:266, in BZ2Picklable.__init__(self, name, mode)
#     264 def __init__(self, name, mode='rb'):
#     265     self._bz_mode = mode
# --> 266     super().__init__(name, mode)
#
# File /ext3/miniconda3/lib/python3.9/bz2.py:85, in BZ2File.__init__(self, filename, mode, compresslevel)
#      82     raise ValueError("Invalid mode: %r" % (mode,))
#      84 if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 85     self._fp = _builtin_open(filename, mode)
#      86     self._closefp = True
#      87     self._mode = mode_code
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Data/equil/kalj_T2_n360_v300_10000_1.lammpstrj'

# %%
temperatures = [1.5, 1, 0.9, 0.8, 0.7, 0.65, 0.6, 0.55, 0.5, 0.475, 0.45]

traj_list = [traj_T1p5, traj_T1, traj_T0p9, traj_T0p8, traj_T0p7, traj_T0p65, traj_T0p6, traj_T0p55, traj_T0p5, traj_T0p475, traj_T0p45]
rdfs = np.empty((3, len(traj_list)), dtype=object)


for traj in traj_list:
    sel1 = traj.select_atoms("type 1")
    sel2 = traj.select_atoms("type 2")
    rdfs[0, traj_list.index(traj)] = rdf.InterRDF(sel1, sel1, nbins=100, range=(0, 10))
    rdfs[1, traj_list.index(traj)] = rdf.InterRDF(sel2, sel2, nbins=100, range=(0, 10))
    rdfs[2, traj_list.index(traj)] = rdf.InterRDF(sel1, sel2, nbins=100, range=(0, 10))
    rdfs[0, traj_list.index(traj)].run()
    rdfs[1, traj_list.index(traj)].run()
    rdfs[2, traj_list.index(traj)].run()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [20], line 6
#       4 temperatures = [1.5, 1, 0.9, 0.8, 0.7, 0.65, 0.6, 0.55, 0.5, 0.475, 0.45]
#       5 #define trajectory list
# ----> 6 traj_list = [traj_T1p5, traj_T1, traj_T0p9, traj_T0p8, traj_T0p7, traj_T0p65, traj_T0p6, traj_T0p55, traj_T0p5, traj_T0p475, traj_T0p45]
#       7 #create empty list to store rdf values
#       8 rdfs = np.empty((3, len(traj_list)), dtype=object)
#
# NameError: name 'traj_T1p5' is not defined

# %%
# figure 1 - RDFs
fig = plt.figure(1)

# set colorblind-friendly palatte 
colors = ['#0077BB', '#33BBEE', '#009988', '#EE7733', '#CC3311', '#EE3377', '#BBBBBB']
# add more colors if needed
colors = colors + ['#332288', '#88CCEE', '#44AA99', '#117733', '#999933', '#DDCC77', '#CC6677', '#882255', '#AA4499']
# set 11 line width, range from 2 to 1
linewidths = np.linspace(2, 1, 11)
# temperature list
temps = ['1.5', '1', '0.9', '0.8', '0.7', '0.65', '0.6', '0.55', '0.5', '0.475', '0.45']

# plot RDFs
for j in range(len(temps)):
    plt.plot(rdfs[0, j].bins, rdfs[0, j].rdf, color=colors[j], linewidth=linewidths[j], label='T'+temps[j], alpha=0.8)
    j += 1
plt.xlabel('r (Å)', fontsize=12)
plt.ylabel('g(r)', fontsize=12)
plt.legend(loc='upper right', fontsize=9, frameon=False)
plt.xlim(0, 10)

# two lines of title
plt.text(x=0.5, y=0.88, s="Radial Distribution Function "+r"$g_{11}(r)$", fontsize=18, ha="center", transform=fig.transFigure)
plt.text(x=0.5, y=0.82, s= "3D KALJ glass-forming liquid, between type 1 and type 1", fontsize=11, ha="center", transform=fig.transFigure)
plt.subplots_adjust(top=0.8, wspace=0.3)

# save figure as pdf in ../Figures
fname = '../Figures/fig1.[3D_KALJ]_RDF_type1_type1.pdf'
plt.savefig(fname, format='pdf', dpi=300, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 traj_list = [trajs['traj_T0475'], trajs['traj_T0500'], trajs['traj_T0550'], trajs['traj_T0600'], trajs['traj_T0650'],  trajs['traj_T0700'], trajs['traj_T0800'], trajs['traj_T0900'], trajs['traj_T1000'], trajs['traj_T1500']]
#       2 # Type 1 and Tpye 1
#       3 rdf_11 = np.empty(10, dtype='object')
#
# KeyError: 'traj_T0475'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [13], line 6
#       3 plt.figure()
#       5 while i < 10:
# ----> 6     plt.plot(rdf_11[i].results.bins, rdf_11[i].results.rdf, label ='T'+Temp[i])
#       7     i += 1
#       9 plt.xlim(0, 10)
#
# NameError: name 'rdf_11' is not defined
