# %%
import sys
import numpy as np
import matplotlib.pyplot as plt

#Read the grid file
grid = np.genfromtxt('/home/as12009/comp-lab-class/Week6/Inputs/topolA/HILLS.txt')

#Plot the negative of the energy column
plt.scatter(grid[:,0]/1000, grid[:,5])
#convert the x axis from ps to ns

#label the axes
plt.xlabel('Time (ns)')
plt.ylabel('Energy(KJ/mol)')
plt.title('Gaussian Height of Alanine A')
plt.show()
#Save the plot
plt.savefig('dialaAheight.png')

# %%
plt.scatter(grid[:,0]/1000, grid[:,2])
#label the axes
plt.xlabel('Time')
plt.ylabel('Raidan')
plt.title('Metadynamics CV Time Evolution')
plt.show()
#Save the plot
plt.savefig('metadynamicscv_10ns.png')
