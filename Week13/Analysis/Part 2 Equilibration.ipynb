# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('/home/as12009/comp-lab-class/Week13/Outputs/NPT-1.ener')

# %%
plt.plot(data[:,1],data[:,4])
plt.xlabel('Time (fs)')
plt.ylabel('Potential Energy (a.u.)')
plt.title('NPT Potential Energy v Time')
plt.savefig('NPT_PEvsTime.png')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data = np.loadtxt('/home/as12009/comp-lab-class/Week13/Outputs/NVT-1.ener')

# %%
plt.plot(data[:,1],data[:,4])
plt.xlabel('Time (fs)')
plt.ylabel('Potential Energy (a.u.)')
plt.title('NVT Potential Energy v Time')
plt.savefig('NVT_PEvsTime.png')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
