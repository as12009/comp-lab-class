# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data1 = np.loadtxt('/home/as12009/comp-lab-class/Week13/Outputs/NPT-1.ener')

# %%
plt.plot(data1[:,1],data1[:,4])
plt.xlabel('Time (fs)')
plt.ylabel('Potential Energy (a.u.)')
plt.title('NPT Potential Energy v Time')
plt.savefig('NPT_PEvsTime.png')
plt.show()

# %%
data2 = np.loadtxt('/home/as12009/comp-lab-class/Week13/Outputs/NVT-1.ener')

# %%
plt.plot(data2[:,1],data2[:,4])
plt.xlabel('Time (fs)')
plt.ylabel('Potential Energy (a.u.)')
plt.title('NVT Potential Energy v Time')
plt.savefig('NVT_PEvsTime.png')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data3 = np.loadtxt('/home/as12009/comp-lab-class/Week13/Outputs/monitor/MONITOR-1.ener')
plt.plot(data3[:,1],data3[:,4])
plt.xlabel('Time (fs)')
plt.ylabel('Potential Energy (a.u.)')
plt.title('QM/MM Potential Energy v Time')
plt.show()

# %%
data4 = np.loadtxt('../Outputs/metad1_initmonitor_freqhills/METADYN-1.ener')

times = data4[:, 1]

PE = data4[:, 4]
plt.plot(times, PE)
plt.xlabel('Time (fs)')
plt.ylabel('Potential Energy (a.u.)')
plt.title('QM/MM Metadynamics Potential Energy v Time')
plt.savefig('QMMM_metahills_PEvsTime.png')
plt.show()

# %%
data5=np.loadtxt('../Outputs/metad1_initmonitor/METADYN-1.ener')

times = data5[:, 1]

PE = data5[:, 4]

plt.plot(times, PE)
plt.xlabel('Time (fs)')
plt.ylabel('Potential Energy (a.u.)')
plt.title('QM/MM Metadynamics Potential Energy vs Time')
plt.savefig('QMMM_meta_PEvsTime.png')
plt.show()
